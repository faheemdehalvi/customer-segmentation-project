# %% [markdown]
# # Data Cleaning
#
# In this notebook, we will perform data cleaning steps to prepare the customer dataset for analysis. This includes handling missing values, removing cancelled orders, and ensuring the dataset is in a suitable format.

# %%
import pandas as pd

# Load the dataset
data_path = '../data/raw/customers.csv'
customers = pd.read_csv(data_path)

# Display the first few rows of the dataset
customers.head()
# Out:
#    customer_id first_name last_name                       email  gender  \
# 0            1       John       Doe        john.doe@example.com    Male
# 1            2       Jane     Smith      jane.smith@example.com  Female
# 2            3        Bob     Brown       bob.brown@example.com    Male
# 3            4      Alice   Johnson   alice.johnson@example.com  Female
# 4            5    Charlie    Wilson  charlie.wilson@example.com    Male
#
#     ip_address         city country  postcode     phone  age  \
# 0  192.168.1.1     New York     USA     10001  555-1234   28
# 1  192.168.1.2  Los Angeles     USA     90001  555-5678   34
# 2  192.168.1.3      Chicago     USA     60601  555-8765   45
# 3  192.168.1.4      Houston     USA     77001  555-4321   29
# 4  192.168.1.5      Phoenix     USA     85001  555-1357   38
#
#   account_creation_date last_purchase_date  total_spent
# 0            2020-01-15         2023-10-01      1500.50
# ...

# %% [markdown]
# ## Handling Missing Values
#
# We will check for missing values in the dataset and decide how to handle them.

# %%
# Check for missing values
missing_values = customers.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Removing Cancelled Orders
#
# We will remove any cancelled orders from the dataset.

# %%
# Remove cancelled orders (no 'OrderStatus' column in this dataset, so skipping)

# Display the shape of the dataset
customers.shape
# Out:
# (10, 14)

# %% [markdown]
# ## Final Dataset Preparation
#
# We will perform any additional cleaning steps necessary to prepare the dataset for analysis.

# %%
# Convert date columns to datetime format
customers['account_creation_date'] = pd.to_datetime(customers['account_creation_date'])
customers['last_purchase_date'] = pd.to_datetime(customers['last_purchase_date'])

# Reset index
customers.reset_index(drop=True, inplace=True)

# Save the cleaned dataset
cleaned_data_path = '../data/processed/cleaned_customers.csv'
customers.to_csv(cleaned_data_path, index=False)

# Display the first few rows of the cleaned dataset
customers.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Faheem\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OrderDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
# ...
